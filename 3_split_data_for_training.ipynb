# %%
import pandas as pd
from glob import glob
from tqdm import tqdm
import argparse
import os, shutil
from sklearn.model_selection import train_test_split

# %%
img_path = '/data/handhygiene/images/'
excel_path = '/data/handhygiene/hh_video_data.xlsx'
csv_path = '/data/handhygiene/handhygiene_label.csv'
test_size= 0.1
val_size = 0.1

df = pd.read_csv(csv_path)
# Out:
#           date                 img_name  target  video_id
# 0     20180806  1_20180806_frames000000       0         1
# 1     20180806  1_20180806_frames000001       0         1
# 2     20180806  1_20180806_frames000002       0         1
# 3     20180806  1_20180806_frames000003       0         1
# 4     20180806  1_20180806_frames000004       0         1
# 5     20180806  1_20180806_frames000005       0         1
# 6     20180806  1_20180806_frames000006       0         1
# 7     20180806  1_20180806_frames000007       0         1
# 8     20180806  1_20180806_frames000008       0         1
# 9     20180806  1_20180806_frames000009       0         1
# 10    20180806  1_20180806_frames000010       0         1
# 11    20180806  1_20180806_frames000011       0         1
# 12    20180806  1_20180806_frames000012       0         1
# 13    20180806  1_20180806_frames000013       0         1
# 14    20180806  1_20180806_frames000014       0         1
# 15    20180806  1_20180806_frames000015       0         1
# 16    20180806  1_20180806_frames000016       0         1
# 17    20180806  1_20180806_frames000017       0         1
# 18    20180806  1_20180806_frames000018       0         1
# 19    20180806  1_20180806_frames000019       0         1
# 20    20180806  1_20180806_frames000020       0         1
# 21    20180806  1_20180806_frames000021       0         1
# 22    20180806  1_20180806_frames000022       0         1
# 23    20180806  1_20180806_frames000023       0         1
# 24    20180806  1_20180806_frames000024       0         1
# 25    20180806  1_20180806_frames000025       0         1
# 26    20180806  1_20180806_frames000026       0         1
# 27    20180806  1_20180806_frames000027       0         1
# 28    20180806  1_20180806_frames000028       0         1
# 29    20180806  1_20180806_frames000029       0         1
# ...        ...                      ...     ...       ...
# 3724  20180920  7_20180920_frames000621       0         7
# 3725  20180920  7_20180920_frames000622       0         7
# 3726  20180920  7_20180920_frames000623       0         7
# 3727  20180920  7_20180920_frames000624       0         7
# 3728  20180920  7_20180920_frames000625       0         7
# 3729  20180920  7_20180920_frames000626       0         7
# 3730  20180920  7_20180920_frames000627       0         7
# 3731  20180920  7_20180920_frames000628       0         7
# 3732  20180920  7_20180920_frames000629       0         7
# 3733  20180920  7_20180920_frames000630       0         7
# 3734  20180920  7_20180920_frames000631       0         7
# 3735  20180920  7_20180920_frames000632       0         7
# 3736  20180920  7_20180920_frames000633       0         7
# 3737  20180920  7_20180920_frames000634       0         7
# 3738  20180920  7_20180920_frames000635       0         7
# 3739  20180920  7_20180920_frames000636       0         7
# 3740  20180920  7_20180920_frames000637       0         7
# 3741  20180920  7_20180920_frames000638       0         7
# 3742  20180920  7_20180920_frames000639       0         7
# 3743  20180920  7_20180920_frames000640       0         7
# 3744  20180920  7_20180920_frames000641       0         7
# 3745  20180920  7_20180920_frames000642       0         7
# 3746  20180920  7_20180920_frames000643       0         7
# 3747  20180920  7_20180920_frames000644       0         7
# 3748  20180920  7_20180920_frames000645       0         7
# 3749  20180920  7_20180920_frames000646       0         7
# 3750  20180920  7_20180920_frames000647       0         7
# 3751  20180920  7_20180920_frames000648       0         7
# 3752  20180920  7_20180920_frames000649       0         7
# 3753  20180920  7_20180920_frames000650       0         7
#
# [3754 rows x 4 columns]

# %%
def split_train_val_test(vids):
    x_train, x_test = train_test_split(vids, test_size=test_size)
    x_train, x_val = train_test_split(x_train, test_size=val_size)
    print(x_train, x_val, x_test)
    for i in ["train", "val", "test"]:
        target_dir = os.path.join(img_path, i)
        if not os.path.exists(target_dir):
            os.mkdir(target_dir)
            
        if i == "train":
            target = x_train
        elif i == "val":
            target = x_val
        elif i == "test":
            target = x_test
        condition_str = i
          
        for video_id in tqdm(target):
            video_id=video_id
            origin_dir = os.path.join(img_path, str(video_id)+'_*')
            os.system("mv %s %s" % (origin_dir, target_dir))
        
        # create empty dataframe
        df_new = df[df['video_id'] == 0]
        for i in target.values:
            add= df[df['video_id'] == i]
            df_new = pd.concat([df_new, pd.DataFrame(add)])
            
        target_path = csv_path.split('.')[-2]
        dest = "%s_%s.csv" % (target_path, condition_str)
        df_new.to_csv(dest, index=False)

# %%
split_by = df['video_id'].drop_duplicates()
split_train_val_test(split_by)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 34.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.98it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# (0       1
# 1755    4
# 1706    2
# 2538    6
# Name: video_id, dtype: int64, 3110    7
# Name: video_id, dtype: int64, 2240    5
# Name: video_id, dtype: int64)
# /data/handhygiene/images/train
# /data/handhygiene/images/val
# /data/handhygiene/images/test
# 100%|██████████| 1/1 [00:00<00:00, 31.13it/s]
